# %% [markdown]
# # Tratamento de dados

# %%
import os
import re
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ftrav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ftrav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def count_words(text):
    words = text.split()
    return len(words)

# %%
def cut_voters(text):
    regex = re.compile('(?P<voters>.+) voted for this decision')
    try:
        text_cut = regex.search(str(text)).group('voters')
    except:
        text_cut = text
    return text_cut

# %%
def extract_meeting_number(sentence):
    match = re.search(r'\d+', sentence)
    if match:
        return match.group()
    else:
        return None

# %%
def preprocess_text(text):

    # Remove newline characters
    text = re.sub(r'\n', ' ', text)

    # Remove tab characters
    text = re.sub(r'\t', ' ', text)

    # Remove Unicode characters
    text = re.sub(r'[^\x00-\x7F]+', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Tokenize text into individual words
    words = nltk.word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Join the words back into a single string
    processed_text = ' '.join(words)

    return processed_text

# %% [markdown]
# ### Statements

# %%
df_statements = pd.read_csv('statements.csv')

# %%
df_statements.tail()
# Out:
#                                               Conteudo                  Data  \
# 135  <div> <p>In the August Meeting, the Copom unan...  2006-08-30T03:00:00Z
# 136  <div> <p>In the July Meeting, the Copom unanim...  2006-07-19T03:00:00Z
# 137  <div> <p>In the May Meeting, the Monetary Poli...  2006-05-31T03:00:00Z
# 138  <div> <p>In the April Meeting, the Monetary Po...  2006-04-19T03:00:00Z
# 139  <div> <p>In the March Meeting, the Banco Centr...  2006-03-08T03:00:00Z
#
#      DataAtualizacao    Id         Titulo  mostrarCabecalho  mostrarRodape
# 135              NaN  2120  121st Meeting             False          False
# 136              NaN  2119  120th Meeting             False          False
# 137              NaN  2118  119th Meeting             False          False
# 138              NaN  2117  118th Meeting             False          False
# 139              NaN  2116  117th Meeting             False          False

# %%
df_statements.loc[30:,'Titulo']
# Out:
# 30                 Copom lowers Selic rate to 6.00% p.a.
# 31     223rd Meeting of the Monetary Policy Committee...
# 32     222nd Meeting of the Monetary Policy Committee...
# 33     221st Meeting of the Monetary Policy Committee...
# 34     220th Meeting of the Monetary Policy Committee...
#                              ...
# 135                                        121st Meeting
# 136                                        120th Meeting
# 137                                        119th Meeting
# 138                                        118th Meeting
# 139                                        117th Meeting
# Name: Titulo, Length: 110, dtype: object

# %%
df_statements['meeting_number'] = df_statements['Titulo'].apply(extract_meeting_number).astype(int)

# %%
df_statements.head()
# Out:
#                                             Conteudo                  Data  \
# 0  <p style="text-align&#58;justify;">The global ...  2023-05-03T21:49:02Z
# 1  <p style="text-align&#58;justify;">Since its p...  2023-03-22T21:33:49Z
# 2  <p style="text-align&#58;justify;">In its 252<...  2023-02-01T21:37:00Z
# 3  <p style="text-align&#58;justify;">In its 251<...  2022-12-07T21:31:38Z
# 4  <p style="text-align&#58;justify;">In its 250<...  2022-10-26T21:39:32Z
#
#    DataAtualizacao    Id                                         Titulo  \
# 0              NaN  2475  Copom maintains the Selic rate at 13.75% p.a.
# 1              NaN  2467  Copom maintains the Selic rate at 13.75% p.a.
# 2              NaN  2463  Copom maintains the Selic rate at 13.75% p.a.
# 3              NaN  2456  Copom maintains the Selic rate at 13.75% p.a.
# 4              NaN  2451  Copom maintains the Selic rate at 13.75% p.a.
#
#    mostrarCabecalho  mostrarRodape  meeting_number
# 0             False          False              13
# 1             False          False              13
# 2             False          False              13
# 3             False          False              13
# 4             False          False              13

# %%
df_statements.loc[30:,'meeting_number']
# Out:
# 30       6
# 31     223
# 32     222
# 33     221
# 34     220
#       ...
# 135    121
# 136    120
# 137    119
# 138    118
# 139    117
# Name: meeting_number, Length: 110, dtype: int32

# %%
for i in range(31, 0, -1):
    number = df_statements.iloc[i, 7]
    df_statements.iloc[i-1, 7] = number + 1

# %%
df_statements.loc[:,'meeting_number']
# Out:
# 0      254
# 1      253
# 2      252
# 3      251
# 4      250
#       ...
# 135    121
# 136    120
# 137    119
# 138    118
# 139    117
# Name: meeting_number, Length: 140, dtype: int32

# %%
df_statements['type'] = 'statement'
df_statements["date"] = df_statements["Data"].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S.%f').dt.strftime('%Y/%m/%d')
df_statements.drop(['Data', 'Id', 'Titulo', 'DataAtualizacao', 'mostrarCabecalho', 'mostrarRodape'], axis=1, inplace=True)

# %%
df_statements.rename(columns={'Conteudo': 'text_raw'}, inplace=True)

# %%
# df_statements.sort_values('Date', inplace=True)
# df_statements.set_index('Date', inplace=True)
df_statements = df_statements.sort_values('meeting_number').copy()

# %%
df_statements['text_raw'] = df_statements['text_raw'].apply(lambda x: BeautifulSoup(x, features="html.parser").get_text())

# %%
df_statements.head()
# Out:
#                                               text_raw  meeting_number  \
# 139   In the March Meeting, the Banco Central do Br...             117
# 138   In the April Meeting, the Monetary Policy Com...             118
# 137   In the May Meeting, the Monetary Policy Commi...             119
# 136   In the July Meeting, the Copom unanimously de...             120
# 135   In the August Meeting, the Copom unanimously ...             121
#
#           type        date
# 139  statement  2006/03/08
# 138  statement  2006/04/19
# 137  statement  2006/05/31
# 136  statement  2006/07/19
# 135  statement  2006/08/30

# %%
# df_statements['Text_raw'][120]

# %%
df_statements['text'] = df_statements['text_raw'].apply(cut_voters).apply(preprocess_text)

# %%
# df_statements['Text'][120]

# %%
df_statements['num_words'] = df_statements['text'].apply(count_words).astype(int)
df_statements['num_words_raw'] = df_statements['text_raw'].apply(count_words).astype(int)

# %%
df_statements.tail(5)
# Out:
#                                             text_raw  meeting_number  \
# 4  In its 250th meeting, the Copom decided to mai...             250
# 3  In its 251st meeting, Copom decided to maintai...             251
# 2  In its 252nd meeting, Copom decided to maintai...             252
# 1  Since its previous meeting of the Monetary Pol...             253
# 0  The global environment remains challenging. Th...             254
#
#         type        date                                               text  \
# 4  statement  2022/10/26  250th meeting , copom decided maintain selic r...
# 3  statement  2022/12/07  251st meeting , copom decided maintain selic r...
# 2  statement  2023/02/01  252nd meeting , copom decided maintain selic r...
# 1  statement  2023/03/22  since previous meeting monetary policy committ...
# 0  statement  2023/05/03  global environment remains challenging . episo...
#
#    num_words  num_words_raw
# 4        498            759
# 3        512            776
# 2        484            842
# 1        444            807
# 0        436            802

# %%
df_statements.shape
# Out:
# (140, 7)

# %%
# df_statements.drop(['text_raw', 'num_words_raw'], axis=1, inplace=True)

# %%
df_statements
# Out:
#                                               text_raw  meeting_number  \
# 139   In the March Meeting, the Banco Central do Br...             117
# 138   In the April Meeting, the Monetary Policy Com...             118
# 137   In the May Meeting, the Monetary Policy Commi...             119
# 136   In the July Meeting, the Copom unanimously de...             120
# 135   In the August Meeting, the Copom unanimously ...             121
# ..                                                 ...             ...
# 4    In its 250th meeting, the Copom decided to mai...             250
# 3    In its 251st meeting, Copom decided to maintai...             251
# 2    In its 252nd meeting, Copom decided to maintai...             252
# 1    Since its previous meeting of the Monetary Pol...             253
# 0    The global environment remains challenging. Th...             254
#
#           type        date                                               text  \
# 139  statement  2006/03/08  march meeting , banco central brasil 's moneta...
# 138  statement  2006/04/19  april meeting , monetary policy committee ( co...
# 137  statement  2006/05/31  may meeting , monetary policy committee ( copo...
# 136  statement  2006/07/19  july meeting , copom unanimously decided reduc...
# 135  statement  2006/08/30  august meeting , copom unanimously decided red...
# ..         ...         ...                                                ...
# 4    statement  2022/10/26  250th meeting , copom decided maintain selic r...
# 3    statement  2022/12/07  251st meeting , copom decided maintain selic r...
# 2    statement  2023/02/01  252nd meeting , copom decided maintain selic r...
# 1    statement  2023/03/22  since previous meeting monetary policy committ...
# 0    statement  2023/05/03  global environment remains challenging . episo...
#
#      num_words  num_words_raw
# 139         55             67
# 138         35             40
# 137         35             40
# 136         30             37
# 135         34             44
# ..         ...            ...
# 4          498            759
# 3          512            776
# 2          484            842
# 1          444            807
# 0          436            802
#
# [140 rows x 7 columns]

# %% [markdown]
# ### Minutes

# %%
df_minutes = pd.read_csv('minutes.csv')

# %%
df_minutes.tail(1)
# Out:
#      BoxDestaque        DataReferencia  Edicao  EsconderCapa  \
# 212          NaN  2000-01-10T02:00:00Z     NaN         False
#
#     EsconderDataReferencia  Grafico   Id  \
# 212                    NaN      NaN  1.0
#
#                                             ImagemCapa  \
# 212  /content/publications/PublishingImages/Capas/c...
#
#                                             Introducao  \
# 212  The minutes of the Monetary Policy Committee’s...
#
#                                      LinkPagina OutrasInformacoes  \
# 212  /en/publications/copomminutes/cronologicos               NaN
#
#                  Titulo                                                Url  \
# 212  42nd Copom minutes  /content/copom/copomminutes/MIN200042-COPOM200...
#
#      Volume  conteudo                  data
# 212     NaN       NaN  2000-01-24T02:00:00Z

# %%
df_minutes.loc[:,'Titulo']
# Out:
# 0                      254th Meeting - May 2-3, 2023
# 1                  253rd Meeting - March 21-22, 2023
# 2      252nd Meeting - January 31 - February 1, 2023
# 3                 251st Meeting - December 6-7, 2022
# 4                250th Meeting - October 25-26, 2022
#                            ...
# 208                               45th Copom minutes
# 209                               44th Copom minutes
# 210                               43nd Copom minutes
# 211                        Changes in Copom meetings
# 212                               42nd Copom minutes
# Name: Titulo, Length: 213, dtype: object

# %%
df_minutes['meeting_number'] = df_minutes['Titulo'].apply(extract_meeting_number)

# %%
df_minutes.tail()
# Out:
#      BoxDestaque        DataReferencia  Edicao  EsconderCapa  \
# 208          NaN  2000-03-30T03:00:00Z     NaN         False
# 209          NaN  2000-02-15T03:00:00Z     NaN         False
# 210          NaN  2000-02-04T02:00:00Z     NaN         False
# 211          NaN  2000-01-19T02:00:00Z     NaN         False
# 212          NaN  2000-01-10T02:00:00Z     NaN         False
#
#     EsconderDataReferencia  Grafico   Id  \
# 208                    NaN      NaN  5.0
# 209                    NaN      NaN  4.0
# 210                    NaN      NaN  3.0
# 211                    NaN      NaN  2.0
# 212                    NaN      NaN  1.0
#
#                                             ImagemCapa  \
# 208  /content/publications/PublishingImages/Capas/c...
# 209  /content/publications/PublishingImages/Capas/c...
# 210  /content/publications/PublishingImages/Capas/c...
# 211  /content/publications/PublishingImages/Capas/c...
# 212  /content/publications/PublishingImages/Capas/c...
#
#                                             Introducao  \
# 208  The minutes of the Monetary Policy Committee’s...
# 209  The minutes of the Monetary Policy Committee’s...
# 210  The minutes of the Monetary Policy Committee’s...
# 211  The minutes of the Monetary Policy Committee’s...
# 212  The minutes of the Monetary Policy Committee’s...
#
#                                      LinkPagina OutrasInformacoes  \
# 208  /en/publications/copomminutes/cronologicos               NaN
# 209  /en/publications/copomminutes/cronologicos               NaN
# 210  /en/publications/copomminutes/cronologicos               NaN
# 211  /en/publications/copomminutes/cronologicos               NaN
# 212  /en/publications/copomminutes/cronologicos               NaN
#
#                         Titulo  \
# 208         45th Copom minutes
# 209         44th Copom minutes
# 210         43nd Copom minutes
# 211  Changes in Copom meetings
# 212         42nd Copom minutes
#
#                                                    Url  Volume  conteudo  \
# 208  /content/copom/copomminutes/MIN200045-COPOM200...     NaN       NaN
# 209  /content/copom/copomminutes/MIN200044-COPOM200...     NaN       NaN
# 210  /content/copom/copomminutes/MIN200043-COPOM200...     NaN       NaN
# 211  /content/copom/copomminutes/CHANG200042-COPOM2...     NaN       NaN
# 212  /content/copom/copomminutes/MIN200042-COPOM200...     NaN       NaN
#
#                      data meeting_number
# 208  2000-03-30T03:00:00Z             45
# 209  2000-02-15T03:00:00Z             44
# 210  2000-02-04T02:00:00Z             43
# 211  2001-08-06T03:00:00Z           None
# 212  2000-01-24T02:00:00Z             42

# %%
df_minutes = df_minutes[df_minutes['meeting_number'].notna()]

# %%
df_minutes['meeting_number'] = df_minutes['meeting_number'].astype(int).copy()

# %%
df_minutes.tail()
# Out:
#      BoxDestaque        DataReferencia  Edicao  EsconderCapa  \
# 207          NaN  2000-05-04T03:00:00Z     NaN         False
# 208          NaN  2000-03-30T03:00:00Z     NaN         False
# 209          NaN  2000-02-15T03:00:00Z     NaN         False
# 210          NaN  2000-02-04T02:00:00Z     NaN         False
# 212          NaN  2000-01-10T02:00:00Z     NaN         False
#
#     EsconderDataReferencia  Grafico   Id  \
# 207                    NaN      NaN  6.0
# 208                    NaN      NaN  5.0
# 209                    NaN      NaN  4.0
# 210                    NaN      NaN  3.0
# 212                    NaN      NaN  1.0
#
#                                             ImagemCapa  \
# 207  /content/publications/PublishingImages/Capas/c...
# 208  /content/publications/PublishingImages/Capas/c...
# 209  /content/publications/PublishingImages/Capas/c...
# 210  /content/publications/PublishingImages/Capas/c...
# 212  /content/publications/PublishingImages/Capas/c...
#
#                                             Introducao  \
# 207  The minutes of the Monetary Policy Committee’s...
# 208  The minutes of the Monetary Policy Committee’s...
# 209  The minutes of the Monetary Policy Committee’s...
# 210  The minutes of the Monetary Policy Committee’s...
# 212  The minutes of the Monetary Policy Committee’s...
#
#                                      LinkPagina OutrasInformacoes  \
# 207  /en/publications/copomminutes/cronologicos               NaN
# 208  /en/publications/copomminutes/cronologicos               NaN
# 209  /en/publications/copomminutes/cronologicos               NaN
# 210  /en/publications/copomminutes/cronologicos               NaN
# 212  /en/publications/copomminutes/cronologicos               NaN
#
#                  Titulo                                                Url  \
# 207  46th Copom minutes  /content/copom/copomminutes/MIN200046-COPOM200...
# 208  45th Copom minutes  /content/copom/copomminutes/MIN200045-COPOM200...
# 209  44th Copom minutes  /content/copom/copomminutes/MIN200044-COPOM200...
# 210  43nd Copom minutes  /content/copom/copomminutes/MIN200043-COPOM200...
# 212  42nd Copom minutes  /content/copom/copomminutes/MIN200042-COPOM200...
#
#      Volume  conteudo                  data  meeting_number
# 207     NaN       NaN  2000-05-04T03:00:00Z              46
# 208     NaN       NaN  2000-03-30T03:00:00Z              45
# 209     NaN       NaN  2000-02-15T03:00:00Z              44
# 210     NaN       NaN  2000-02-04T02:00:00Z              43
# 212     NaN       NaN  2000-01-24T02:00:00Z              42

# %%
df_minutes['type'] = 'minutes'
# df_minutes["Minutes_Date"] = df_minutes["data"].apply(pd.to_datetime).dt.strftime('%Y/%m/%d')
df_minutes["date"] = df_minutes["DataReferencia"].apply(pd.to_datetime).dt.strftime('%Y/%m/%d')

# %%
df_minutes.tail()
# Out:
#      BoxDestaque        DataReferencia  Edicao  EsconderCapa  \
# 207          NaN  2000-05-04T03:00:00Z     NaN         False
# 208          NaN  2000-03-30T03:00:00Z     NaN         False
# 209          NaN  2000-02-15T03:00:00Z     NaN         False
# 210          NaN  2000-02-04T02:00:00Z     NaN         False
# 212          NaN  2000-01-10T02:00:00Z     NaN         False
#
#     EsconderDataReferencia  Grafico   Id  \
# 207                    NaN      NaN  6.0
# 208                    NaN      NaN  5.0
# 209                    NaN      NaN  4.0
# 210                    NaN      NaN  3.0
# 212                    NaN      NaN  1.0
#
#                                             ImagemCapa  \
# 207  /content/publications/PublishingImages/Capas/c...
# 208  /content/publications/PublishingImages/Capas/c...
# 209  /content/publications/PublishingImages/Capas/c...
# 210  /content/publications/PublishingImages/Capas/c...
# 212  /content/publications/PublishingImages/Capas/c...
#
#                                             Introducao  \
# 207  The minutes of the Monetary Policy Committee’s...
# 208  The minutes of the Monetary Policy Committee’s...
# 209  The minutes of the Monetary Policy Committee’s...
# 210  The minutes of the Monetary Policy Committee’s...
# 212  The minutes of the Monetary Policy Committee’s...
#
#                                      LinkPagina OutrasInformacoes  \
# 207  /en/publications/copomminutes/cronologicos               NaN
# 208  /en/publications/copomminutes/cronologicos               NaN
# 209  /en/publications/copomminutes/cronologicos               NaN
# 210  /en/publications/copomminutes/cronologicos               NaN
# 212  /en/publications/copomminutes/cronologicos               NaN
#
#                  Titulo                                                Url  \
# 207  46th Copom minutes  /content/copom/copomminutes/MIN200046-COPOM200...
# 208  45th Copom minutes  /content/copom/copomminutes/MIN200045-COPOM200...
# 209  44th Copom minutes  /content/copom/copomminutes/MIN200044-COPOM200...
# 210  43nd Copom minutes  /content/copom/copomminutes/MIN200043-COPOM200...
# 212  42nd Copom minutes  /content/copom/copomminutes/MIN200042-COPOM200...
#
#      Volume  conteudo                  data  meeting_number     type  \
# 207     NaN       NaN  2000-05-04T03:00:00Z              46  minutes
# 208     NaN       NaN  2000-03-30T03:00:00Z              45  minutes
# 209     NaN       NaN  2000-02-15T03:00:00Z              44  minutes
# 210     NaN       NaN  2000-02-04T02:00:00Z              43  minutes
# 212     NaN       NaN  2000-01-24T02:00:00Z              42  minutes
#
#            date
# 207  2000/05/04
# 208  2000/03/30
# 209  2000/02/15
# 210  2000/02/04
# 212  2000/01/10

# %%
df_minutes.drop(['BoxDestaque', 'DataReferencia', 'Edicao', 'EsconderCapa', 
                 'EsconderDataReferencia', 'Grafico', 'Id', 
                 'ImagemCapa', 'Introducao', 'LinkPagina', 'Titulo',
                 'Url', 'Volume', 'conteudo', 'data'], axis=1, inplace=True)

# %%
df_minutes.rename(columns={'OutrasInformacoes': 'text_raw'}, inplace=True)

# %%
# df_minutes.sort_values('Date', inplace=True)
# df_minutes.set_index('Date', inplace=True)
df_minutes = df_minutes.sort_values('meeting_number').copy()

# %%
df_minutes = df_minutes[df_minutes['text_raw'].notna()]

# %%
df_minutes
# Out:
#                                              text_raw  meeting_number  \
# 22  <div id="atacompleta"><div id="ataconteudo"><p...             232
# 21  <div id="atacompleta"><div id="ataconteudo"><h...             233
# 20  <div id="atacompleta"><div id="ataconteudo"><h...             234
# 19  <div id="atacompleta"><div id="ataconteudo"><h...             235
# 18  <div id="atacompleta"><div id="ataconteudo"><h...             236
# 17  <div id="atacompleta"><div id="ataconteudo"><h...             237
# 16  <div id="atacompleta"><div id="ataconteudo"><h...             238
# 15  <div id="atacompleta"><div id="ataconteudo"><h...             239
# 14  <div id="atacompleta"><div id="ataconteudo"><h...             240
# 13  <div id="atacompleta"><div id="ataconteudo"><h...             241
# 12  <div id="atacompleta"><div id="ataconteudo"><h...             242
# 11  <div id="atacompleta"><div id="ataconteudo"><h...             243
# 10  <div id="atacompleta"><div id="ataconteudo"><h...             244
# 9   <div id="atacompleta"><div id="ataconteudo"><h...             245
# 8   <div id="atacompleta"><div id="ataconteudo"><h...             246
# 7   <div id="atacompleta"><div id="ataconteudo"><h...             247
# 6   <div id="atacompleta"><div id="ataconteudo"><h...             248
# 5   <div id="atacompleta"><div id="ataconteudo"><h...             249
# 4   <div id="atacompleta"><div id="ataconteudo"><h...             250
# 3   <div id="atacompleta"><div id="ataconteudo"><h...             251
# 2   <div id="atacompleta"><div id="ataconteudo"><h...             252
# 1   <div id="atacompleta"><div id="ataconteudo"><h...             253
# 0   <div id="atacompleta"><div id="ataconteudo"><h...             254
#
#        type        date
# 22  minutes  2020/08/05
# 21  minutes  2020/09/16
# 20  minutes  2020/10/28
# 19  minutes  2020/12/09
# 18  minutes  2021/01/20
# 17  minutes  2021/03/17
# 16  minutes  2021/05/05
# 15  minutes  2021/06/16
# 14  minutes  2021/08/04
# 13  minutes  2021/09/22
# 12  minutes  2021/10/27
# 11  minutes  2021/12/08
# 10  minutes  2022/02/02
# 9   minutes  2022/03/16
# 8   minutes  2022/05/04
# 7   minutes  2022/06/15
# 6   minutes  2022/08/03
# 5   minutes  2022/09/21
# 4   minutes  2022/10/26
# 3   minutes  2022/12/07
# 2   minutes  2023/02/01
# 1   minutes  2023/03/22
# 0   minutes  2023/05/03

# %%
df_minutes['text_raw'] = df_minutes['text_raw'].apply(lambda x: BeautifulSoup(x, features="html.parser").get_text())

# %%
df_minutes['text'] = df_minutes['text_raw'].apply(cut_voters)

# %%
df_minutes['num_words'] = df_minutes['text'].apply(count_words).astype(int)
df_minutes['num_words_raw'] = df_minutes['text_raw'].apply(count_words).astype(int)

# %%
df_minutes.head(5)
# Out:
#                                              text_raw  meeting_number  \
# 22  1. Regarding the global outlook, the Covid-19 ...             232
# 21  A) Update of economic outlook and Copom’s base...             233
# 20  A) Update of economic outlook and Copom’s base...             234
# 19  A) Update of economic outlook and Copom’s base...             235
# 18  A) Update of economic outlook and Copom’s base...             236
#
#        type        date                                               text  \
# 22  minutes  2020/08/05  1. Regarding the global outlook, the Covid-19 ...
# 21  minutes  2020/09/16  A) Update of economic outlook and Copom’s base...
# 20  minutes  2020/10/28  A) Update of economic outlook and Copom’s base...
# 19  minutes  2020/12/09  A) Update of economic outlook and Copom’s base...
# 18  minutes  2021/01/20  A) Update of economic outlook and Copom’s base...
#
#     num_words  num_words_raw
# 22       1811           2114
# 21       1750           2049
# 20       1563           1887
# 19       1529           1861
# 18       1478           1810

# %%
df_minutes.shape
# Out:
# (23, 7)

# %%
# df_minutes.drop(['text_raw', 'num_words_raw'], axis=1, inplace=True)

# %%
df_minutes.head()
# Out:
#                                              text_raw  meeting_number  \
# 22  1. Regarding the global outlook, the Covid-19 ...             232
# 21  A) Update of economic outlook and Copom’s base...             233
# 20  A) Update of economic outlook and Copom’s base...             234
# 19  A) Update of economic outlook and Copom’s base...             235
# 18  A) Update of economic outlook and Copom’s base...             236
#
#        type        date                                               text  \
# 22  minutes  2020/08/05  1. Regarding the global outlook, the Covid-19 ...
# 21  minutes  2020/09/16  A) Update of economic outlook and Copom’s base...
# 20  minutes  2020/10/28  A) Update of economic outlook and Copom’s base...
# 19  minutes  2020/12/09  A) Update of economic outlook and Copom’s base...
# 18  minutes  2021/01/20  A) Update of economic outlook and Copom’s base...
#
#     num_words  num_words_raw
# 22       1811           2114
# 21       1750           2049
# 20       1563           1887
# 19       1529           1861
# 18       1478           1810

# %% [markdown]
# ### Decisions

# %%
df_decisions = pd.read_csv('decisions.csv')

# %%
df_decisions.loc[:,'NumeroReuniaoCopom']
# Out:
# 0      254.0
# 1      253.0
# 2      252.0
# 3      251.0
# 4      250.0
#        ...
# 257      5.0
# 258      4.0
# 259      3.0
# 260      2.0
# 261      1.0
# Name: NumeroReuniaoCopom, Length: 262, dtype: float64

# %%
df_decisions['NumeroReuniaoCopom'].value_counts()
# Out:
# 34.0     4
# 33.0     3
# 48.0     2
# 35.0     2
# 45.0     2
#         ..
# 165.0    1
# 164.0    1
# 163.0    1
# 162.0    1
# 1.0      1
# Name: NumeroReuniaoCopom, Length: 254, dtype: int64

# %%
df_decisions.drop(['DataFimVigencia', 'DataInicioVigencia', 'TaxaSelicEfetivaAnualizada',
                 'TaxaSelicEfetivaVigencia', 'TaxaTban', 'UsoMetaSelic', 'ReuniaoExtraordinaria',
                 'Vies'], axis=1, inplace=True)

# %%
df_decisions["DataReuniaoCopom"] = df_decisions["DataReuniaoCopom"].apply(pd.to_datetime).dt.strftime('%Y/%m/%d')

# %%
df_decisions.rename(columns={'DataReuniaoCopom': 'date', 
                             'MetaSelic': 'selic', 
                             'NumeroReuniaoCopom': 'meeting_number'
                            }, inplace=True)

# %%
df_decisions['meeting_number'] = df_decisions['meeting_number'].astype(int).copy()

# %%
df_decisions
# Out:
#            date  selic  meeting_number
# 0    2023/05/03  13.75             254
# 1    2023/03/22  13.75             253
# 2    2023/02/01  13.75             252
# 3    2022/12/07  13.75             251
# 4    2022/10/26  13.75             250
# ..          ...    ...             ...
# 257  1996/10/23   1.78               5
# 258  1996/09/23   1.82               4
# 259  1996/08/21   1.88               3
# 260  1996/07/30   1.90               2
# 261  1996/06/26   1.90               1
#
# [262 rows x 3 columns]

# %%
# df_decisions = df_decisions[df_decisions['Date'] != 'NaT']

# %%
# df_decisions = df_decisions.sort_values('Date').copy()
# df_decisions.set_index('Date', inplace=True)
df_decisions = df_decisions.sort_values('meeting_number').copy()

# %%
df_decisions['decision'] = np.nan
df_decisions['decision_txt'] = ''

# %%
df_decisions['meeting_number'].count()
# Out:
# 262

# %%
for i in range(len(df_decisions)-1):
    df_decisions.iloc[i+1,3] = df_decisions.iloc[i+1,1] - df_decisions.iloc[i,1]

# %%
def decision_txt(num):
    if num == 0:
        return 'mantain'
    elif num >= 0:
        return 'increase'
    elif num <= 0:
        return 'decrease'
    else:
        return ''

# %%
for i in range(len(df_decisions)-1):
    df_decisions.iloc[i+1, 4] = decision_txt(df_decisions.iloc[i+1, 3])

# %%
df_decisions.head()
# Out:
#            date  selic  meeting_number  decision decision_txt
# 261  1996/06/26   1.90               1       NaN
# 260  1996/07/30   1.90               2      0.00      mantain
# 259  1996/08/21   1.88               3     -0.02     decrease
# 258  1996/09/23   1.82               4     -0.06     decrease
# 257  1996/10/23   1.78               5     -0.04     decrease

# %% [markdown]
# ### Labels

# %%
df_decisions['label_hawk_dove'] = None
df_decisions['label_next_meet'] = None

# %%
i = 0

for i in range(len(df_decisions)-1):
    decisao_atual = df_decisions.iloc[i, 3]
    decisao_seguite =  df_decisions.iloc[i+1, 3]
    decisao_seguite_txt = df_decisions.iloc[i+1, 4]    
        
    if decisao_seguite_txt == 'decrease':
        if decisao_seguite == decisao_atual:
            resultado = 'dovish'
        elif decisao_seguite > decisao_atual:
            resultado = 'dovish' # less dovish
        else:
            resultado = 'dovish' # more dovish
    elif decisao_seguite_txt == 'increase':
        if decisao_seguite == decisao_atual:
            resultado = 'hawkish'
        elif decisao_seguite > decisao_atual:
            resultado = 'hawkish' # more hawkish
        else:
            resultado = 'hawkish' # less hawkish
    elif decisao_seguite_txt == 'mantain':
        if decisao_atual < 0: 
            resultado = 'hawkish' # parou de cortar
        elif decisao_atual > 0:
            resultado = 'dovish' # parou de elevar
        else:
            resultado = 'neutral' # manteve
    
    df_decisions.iloc[i, 5] = resultado

# %%
df_decisions.head()
# Out:
#            date  selic  meeting_number  decision decision_txt label_hawk_dove  \
# 261  1996/06/26   1.90               1       NaN                      neutral
# 260  1996/07/30   1.90               2      0.00      mantain          dovish
# 259  1996/08/21   1.88               3     -0.02     decrease          dovish
# 258  1996/09/23   1.82               4     -0.06     decrease          dovish
# 257  1996/10/23   1.78               5     -0.04     decrease          dovish
#
#     label_next_meet
# 261            None
# 260            None
# 259            None
# 258            None
# 257            None

# %%
for i in range(len(df_decisions)-1):
    df_decisions.iloc[i, 6] = df_decisions.iloc[i+1, 4]

# %%
df_decisions.head()
# Out:
#            date  selic  meeting_number  decision decision_txt label_hawk_dove  \
# 261  1996/06/26   1.90               1       NaN                      neutral
# 260  1996/07/30   1.90               2      0.00      mantain          dovish
# 259  1996/08/21   1.88               3     -0.02     decrease          dovish
# 258  1996/09/23   1.82               4     -0.06     decrease          dovish
# 257  1996/10/23   1.78               5     -0.04     decrease          dovish
#
#     label_next_meet
# 261         mantain
# 260        decrease
# 259        decrease
# 258        decrease
# 257        decrease

# %% [markdown]
# ### Merge columns

# %%
df1 = pd.merge(df_statements, df_minutes, how="outer")

# %%
df1 = df1.sort_values('meeting_number').copy()

# %%
df1
# Out:
#                                               text_raw  meeting_number  \
# 0     In the March Meeting, the Banco Central do Br...             117
# 1     In the April Meeting, the Monetary Policy Com...             118
# 2     In the May Meeting, the Monetary Policy Commi...             119
# 3     In the July Meeting, the Copom unanimously de...             120
# 4     In the August Meeting, the Copom unanimously ...             121
# ..                                                 ...             ...
# 137  In its 252nd meeting, Copom decided to maintai...             252
# 161  A) Update of economic outlook and Copom’s scen...             253
# 138  Since its previous meeting of the Monetary Pol...             253
# 139  The global environment remains challenging. Th...             254
# 162  A) Update of economic outlook and Copom’s scen...             254
#
#           type        date                                               text  \
# 0    statement  2006/03/08  march meeting , banco central brasil 's moneta...
# 1    statement  2006/04/19  april meeting , monetary policy committee ( co...
# 2    statement  2006/05/31  may meeting , monetary policy committee ( copo...
# 3    statement  2006/07/19  july meeting , copom unanimously decided reduc...
# 4    statement  2006/08/30  august meeting , copom unanimously decided red...
# ..         ...         ...                                                ...
# 137  statement  2023/02/01  252nd meeting , copom decided maintain selic r...
# 161    minutes  2023/03/22  A) Update of economic outlook and Copom’s scen...
# 138  statement  2023/03/22  since previous meeting monetary policy committ...
# 139  statement  2023/05/03  global environment remains challenging . episo...
# 162    minutes  2023/05/03  A) Update of economic outlook and Copom’s scen...
#
#      num_words  num_words_raw
# 0           55             67
# 1           35             40
# 2           35             40
# 3           30             37
# 4           34             44
# ..         ...            ...
# 137        484            842
# 161       2748           3230
# 138        444            807
# 139        436            802
# 162       2501           2977
#
# [163 rows x 7 columns]

# %%
df2 = pd.merge(df1, df_decisions, how="outer", on=['meeting_number'])

# %%
df = df2.sort_values('meeting_number').copy()

# %%
df.head()
# Out:
#     text_raw  meeting_number type date_x text  num_words  num_words_raw  \
# 163      NaN               1  NaN    NaN  NaN        NaN            NaN
# 164      NaN               2  NaN    NaN  NaN        NaN            NaN
# 165      NaN               3  NaN    NaN  NaN        NaN            NaN
# 166      NaN               4  NaN    NaN  NaN        NaN            NaN
# 167      NaN               5  NaN    NaN  NaN        NaN            NaN
#
#          date_y  selic  decision decision_txt label_hawk_dove label_next_meet
# 163  1996/06/26   1.90       NaN                      neutral         mantain
# 164  1996/07/30   1.90      0.00      mantain          dovish        decrease
# 165  1996/08/21   1.88     -0.02     decrease          dovish        decrease
# 166  1996/09/23   1.82     -0.06     decrease          dovish        decrease
# 167  1996/10/23   1.78     -0.04     decrease          dovish        decrease

# %%
df = df[df['selic'].notna()]

# %%
df = df[df['text'].notna()]

# %%
df = df[['meeting_number', 'date_x', 'date_y', 'selic', 'decision', 'decision_txt', 
         'type', 'text', 'num_words', 'text_raw', 'num_words_raw', 'label_hawk_dove', 'label_next_meet']]

# %%
df
# Out:
#      meeting_number      date_x      date_y  selic  decision decision_txt  \
# 0               117  2006/03/08  2006/03/08  16.50     -0.75     decrease
# 1               118  2006/04/19  2006/04/19  15.75     -0.75     decrease
# 2               119  2006/05/31  2006/05/31  15.25     -0.50     decrease
# 3               120  2006/07/19  2006/07/19  14.75     -0.50     decrease
# 4               121  2006/08/30  2006/08/30  14.25     -0.50     decrease
# ..              ...         ...         ...    ...       ...          ...
# 158             252  2023/02/01  2023/02/01  13.75      0.00      mantain
# 159             253  2023/03/22  2023/03/22  13.75      0.00      mantain
# 160             253  2023/03/22  2023/03/22  13.75      0.00      mantain
# 162             254  2023/05/03  2023/05/03  13.75      0.00      mantain
# 161             254  2023/05/03  2023/05/03  13.75      0.00      mantain
#
#           type                                               text  num_words  \
# 0    statement  march meeting , banco central brasil 's moneta...       55.0
# 1    statement  april meeting , monetary policy committee ( co...       35.0
# 2    statement  may meeting , monetary policy committee ( copo...       35.0
# 3    statement  july meeting , copom unanimously decided reduc...       30.0
# 4    statement  august meeting , copom unanimously decided red...       34.0
# ..         ...                                                ...        ...
# 158  statement  252nd meeting , copom decided maintain selic r...      484.0
# 159    minutes  A) Update of economic outlook and Copom’s scen...     2748.0
# 160  statement  since previous meeting monetary policy committ...      444.0
# 162    minutes  A) Update of economic outlook and Copom’s scen...     2501.0
# 161  statement  global environment remains challenging . episo...      436.0
#
#                                               text_raw  num_words_raw  \
# 0     In the March Meeting, the Banco Central do Br...           67.0
# 1     In the April Meeting, the Monetary Policy Com...           40.0
# 2     In the May Meeting, the Monetary Policy Commi...           40.0
# 3     In the July Meeting, the Copom unanimously de...           37.0
# 4     In the August Meeting, the Copom unanimously ...           44.0
# ..                                                 ...            ...
# 158  In its 252nd meeting, Copom decided to maintai...          842.0
# 159  A) Update of economic outlook and Copom’s scen...         3230.0
# 160  Since its previous meeting of the Monetary Pol...          807.0
# 162  A) Update of economic outlook and Copom’s scen...         2977.0
# 161  The global environment remains challenging. Th...          802.0
#
#     label_hawk_dove label_next_meet
# 0            dovish        decrease
# 1            dovish        decrease
# 2            dovish        decrease
# 3            dovish        decrease
# 4            dovish        decrease
# ..              ...             ...
# 158         neutral         mantain
# 159         neutral         mantain
# 160         neutral         mantain
# 162            None            None
# 161            None            None
#
# [163 rows x 13 columns]

# %%
df.to_csv('df_copom_label_en.csv', index=True)
